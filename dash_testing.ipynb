# %%
#Tutorial on Dash app elements

import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.graph_objs as go

# %%
#simple barplot

app = dash.Dash()
colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}
app.layout = html.Div(style={'backgroundColor': colors['background']}, children=[
    html.H1(
        children='Hello Dash',
        style={
            'textAlign': 'center',
            'color': colors['text']
        }
    ),
    html.Div(children='Dash: A web application framework for Python.', style={
        'textAlign': 'center',
        'color': colors['text']
    }),
    dcc.Graph(
        id='Graph1',
        figure={
            'data': [
                {'x': [1, 2, 3], 'y': [4, 1, 2], 'type': 'bar', 'name': 'SF'},
                {'x': [1, 2, 3], 'y': [2, 4, 5], 'type': 'bar', 'name': u'Montréal'},
            ],
            'layout': {
                'plot_bgcolor': colors['background'],
                'paper_bgcolor': colors['background'],
                'font': {
                    'color': colors['text']
                }
            }
        }
    )
])
app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [29/Apr/2020 14:13:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:13] "GET /_dash-component-suites/dash_renderer/react@16.v1_2_2m1580842230.8.6.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:13] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_2_2m1580842230.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:13] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_8_1m1582848776.js HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:13] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_2_2m1580842230.8.6.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:13] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_8_1m1582848776.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:13] "GET /_dash-component-suites/dash_renderer/dash_renderer.v1_2_2m1580842230.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:13] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_2_2m1580842230.7.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:13] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_0_2m1573845875.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:14] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:14] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:14] "GET /_dash-component-suites/dash_core_components/async-graph.v1_8_1m1582838719.js HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:14] "GET /_favicon.ico?v=1.9.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2020 14:13:14] "GET /_dash-component-suites/dash_core_components/async-plotlyjs.v1_8_1m1582838719.js HTTP/1.1" 200 -

# %%
df = pd.read_csv(
    'https://gist.githubusercontent.com/chriddyp/' +
    '5d1ea79569ed194d432e56108a04d188/raw/' +
    'a9f9e8076b837d541398e999dcbac2b2826a81f8/'+
    'gdp-life-exp-2007.csv')

df.head(10)
# Out:
#    Unnamed: 0      country continent   population  life expectancy  \
# 0          11  Afghanistan      Asia   31889923.0           43.828
# 1          23      Albania    Europe    3600523.0           76.423
# 2          35      Algeria    Africa   33333216.0           72.301
# 3          47       Angola    Africa   12420476.0           42.731
# 4          59    Argentina  Americas   40301927.0           75.320
# 5          71    Australia   Oceania   20434176.0           81.235
# 6          83      Austria    Europe    8199783.0           79.829
# 7          95      Bahrain      Asia     708573.0           75.635
# 8         107   Bangladesh      Asia  150448339.0           64.062
# 9         119      Belgium    Europe   10392226.0           79.441
#
#    gdp per capita
# 0      974.580338
# 1     5937.029526
# 2     6223.367465
# 3     4797.231267
# 4    12779.379640
# 5    34435.367440
# 6    36126.492700
# 7    29796.048340
# 8     1391.253792
# 9    33692.605080

# %%
app = dash.Dash()

app.layout = html.Div([
    dcc.Graph(
        id='life-exp-vs-gdp',
        figure={
            'data': [
                go.Scatter(
                    x=df[df['continent'] == i]['gdp per capita'],
                    y=df[df['continent'] == i]['life expectancy'],
                    text=df[df['continent'] == i]['country'],
                    mode='markers',
                    opacity=0.8,
                    marker={
                        'size': 15,
                        'line': {'width': 0.5, 'color': 'white'}
                    },
                    name=i
                ) for i in df.continent.unique()
            ],
            'layout': go.Layout(
                xaxis={'type': 'log', 'title': 'GDP Per Capita'},
                yaxis={'title': 'Life Expectancy'},
                margin={'l': 40, 'b': 40, 't': 10, 'r': 10},
                legend={'x': 0, 'y': 1},
                hovermode='closest'
            )
        }
    )
])

app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
